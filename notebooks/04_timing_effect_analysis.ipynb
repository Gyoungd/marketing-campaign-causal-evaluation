# %% [markdown]
# # Timing Effect & Interaction Analysis (Observational Robustness Check)

# %% [markdown]
# ## Executive Summary
#
# This notebook checks whether the conversion advantage of cellular contact over telephone holds in every campaign month, or only in some.
#
# Two logistic regressions with robust (HC1) standard errors:
# 1. The average adjusted effect of contact method, without macroeconomic controls.
# 2. A contact × month interaction model, which lets the channel effect differ by month.
#
# Results:
# - On average, cellular contact carries 2.3 times the conversion odds of telephone (OR 2.33, 95% CI 2.14–2.53).
# - Month-level odds ratios run from 0.76 (October) to 8.70 (June).
# - Four of ten months (May, June, July, September) have intervals that exclude 1. The other six do not.
#
# The advantage is real on average and uneven across months. 84.7% of telephone contacts fall in May and June, so month and channel cannot be fully separated in this data.
#
# <!-- KR: cellular의 전환 우위가 모든 캠페인 월에서 성립하는지, 일부 월에서만 성립하는지 확인한다.
# 평균 adjusted OR 2.33 (95% CI 2.14–2.53). 월별 OR은 0.76(10월)~8.70(6월). CI가 1을 제외하는 달은 4개(5·6·7·9월).
# telephone 접촉의 84.7%가 5·6월에 몰려 있어 월과 채널을 완전히 분리할 수 없다. -->

# %% [markdown]
# ## 1. Purpose of the Analysis
#
# The dataset contains a month variable without year separation.
# Therefore, a true Difference-in-Differences design cannot be implemented.
#
# Instead, we use a contact × month interaction model as a robustness check to examine:
#
# - Whether the cellular channel maintains a consistent advantage.
# - Or whether its effect varies across months.
#
# This analysis focuses on timing heterogeneity rather than causal policy inference.

# %%
# Call Libraries
import numpy as np
import pandas as pd

import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

# %%
# Load data
df = pd.read_csv('../data/preprocessed-bank-data.csv')

df.info()
df.head(4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  campaign        41188 non-null  int64
#  11  pdays           41188 non-null  int64
#  12  previous        41188 non-null  int64
#  13  poutcome        41188 non-null  object
#  14  emp.var.rate    41188 non-null  float64
#  15  cons.price.idx  41188 non-null  float64
#  16  cons.conf.idx   41188 non-null  float64
# ...

# %%
# Set the category: telephone is the baseline
df['contact'] = pd.Categorical(df['contact'], categories=['telephone', 'cellular'])
df['month'] = pd.Categorical(df['month'])

# Data checks that decide the control set (see the markdown cell before the controls)
print(pd.crosstab(df['default'], df['y']))
print('housing unknown == loan unknown on every row:',
      ((df['housing'] == 'unknown') == (df['loan'] == 'unknown')).all(),
      '| rows:', (df['housing'] == 'unknown').sum())

# loan: fold 'unknown' into 'no'. The 990 unknown rows are still flagged by housing == 'unknown'.
df['loan_known'] = df['loan'].replace({'unknown': 'no'})
# Out:
# y            0     1
# default
# no       28391  4197
# unknown   8154   443
# yes          3     0
# housing unknown == loan unknown on every row: True | rows: 990

# %% [markdown]
# ## 2. Model Specification
#
# ### 2.1 Baseline Adjusted Model
#
# #### Model
# `conversion ~ contact + controls` (excluding macro variables)
#
# Macro variables are excluded due to high collinearity with month.

# %% [markdown]
# #### Two control variables need handling before fitting
#
# `default` (has credit in default?) has three levels, and the `yes` level has 3 rows with 0 conversions. A logit coefficient for that level runs to −19.7 and the robust sandwich covariance breaks (SE in the billions). The variable is dropped. Three rows cannot carry a confounder adjustment either way.
#
# `housing` and `loan` share the same 990 `unknown` rows. With both entered as three-level factors the design matrix contains two identical columns, and the Hessian is singular. `loan` is recoded so `unknown` joins `no`; the `unknown` group is still identified through `housing`.
#
# Both problems were found because `m_base` originally printed a 95% CI of [0.01, 476] for the contact term.
#
# <!-- KR: default는 'yes'가 3건·전환 0건이라 계수가 −19.7로 발산하고 robust SE가 터진다 → 제거.
# housing과 loan의 'unknown' 990행이 완전히 동일해 design matrix에 같은 열이 두 개 생기고 Hessian이 singular → loan의 unknown을 no로 합침(unknown 정보는 housing에 남음).
# 원래 m_base가 contact CI [0.01, 476]을 출력한 것이 발견 계기. -->

# %%
# Controls without macro variables (emp.var.rate, euribor3m etc. move with month, so they are excluded here)
# 'default' dropped: 3 'yes' rows, 0 conversions -> separation.
# 'loan' replaced by 'loan_known': its 'unknown' level duplicated housing's.
controls_no_macro = [
    'age',
    'campaign',
    'pdays',
    'previous',

    'C(job)',
    'C(marital)',
    'C(education)',
    'C(housing)',
    'C(loan_known)',
    'C(day_of_week)',
    'C(poutcome)']

# %%
# Baseline Adjusted Model
f_base = 'y ~ C(contact) +' + '+'.join(controls_no_macro)

m_base = smf.glm(
    formula = f_base,
    data = df,
    family = sm.families.Binomial()
).fit(cov_type='HC1') # Robust standard errors

m_base.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                      y   No. Observations:                41188
# Model:                            GLM   Df Residuals:                    41152
# Model Family:                Binomial   Df Model:                           35
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -12616.
# Date:                Mon, 21 Sep 2026   Deviance:                       25232.
# Time:                        00:37:23   Pearson chi2:                 4.15e+04
# No. Iterations:                     6   Pseudo R-squ. (CS):            0.08739
# Covariance Type:                  HC1
# ...
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
term = 'C(contact)[T.cellular]'
b  = m_base.params[term]
se = m_base.bse[term]

pd.DataFrame([{
    'term': 'cellular vs telephone (Average)',
    'Odds Ratio': np.exp(b),
    'CI Lower': np.exp(b - 1.96 * se),
    'CI Upper': np.exp(b + 1.96 * se),
    'robust SE (log-odds)': se,
    'p-value': m_base.pvalues[term]
}])
# Out:
#                               term  Odds Ratio  CI Lower  CI Upper  \
# 0  cellular vs telephone (Average)    2.327298  2.140181  2.530775
#
#    robust SE (log-odds)       p-value
# 0              0.042764  7.599442e-87

# %% [markdown]
# ### Result
#
# With the corrected control set, the average adjusted effect of cellular contact is OR 2.33, 95% CI [2.14, 2.53], robust SE 0.043 on the log-odds scale. The interval sits well above 1.
#
# Before the fix the same model printed OR 2.24 with a CI of [0.01, 476]. The point estimate barely moved; the interval did, because the two broken control terms were adding noise to the covariance matrix and not to the estimate itself.
#
# #### Interpretation
#
# After adjustment, cellular contact is associated with 2.3 times the conversion odds of telephone on average. Notebook 03, with a different control set that includes macroeconomic variables, gives 2.16 [1.87, 2.49]. The two estimates overlap, which is the robustness check this notebook exists for. Whether the average holds month by month is the next question.
#
# <!-- KR: 수정된 control set으로 평균 adjusted OR 2.33 [2.14, 2.53], robust SE 0.043.
# 수정 전 같은 모델은 OR 2.24, CI [0.01, 476]이었다. 점추정치는 거의 그대로이고 구간만 바뀌었다. 깨진 control 두 개가 추정치가 아니라 공분산에 노이즈를 넣고 있었기 때문이다.
# 03 노트북(macro 포함, 다른 control set)의 2.16 [1.87, 2.49]과 겹친다. 이것이 이 노트북의 robustness check 역할이다. -->

# %% [markdown]
# ### 2.2 Timing Heterogeneity Model
#
# #### Model
# `conversion ~ contact × month + controls`
#
# This model allows the contact effect to vary by month.
#
# The interaction terms reveal substantial variation across months. Some months show elevated odds ratios for cellular contact, while others show no meaningful difference.
#
# This suggests that channel effectiveness is time-dependent rather than constant.

# %%
# Timing heterogeneity model (contact x month interaction)

f_time = 'y ~ C(contact) * C(month) + ' + '+'.join(controls_no_macro)

m_time = smf.glm(
    formula = f_time,
    data = df,
    family = sm.families.Binomial()
).fit(cov_type='HC1') # Robust standard errors

m_time.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:                      y   No. Observations:                41188
# Model:                            GLM   Df Residuals:                    41134
# Model Family:                Binomial   Df Model:                           53
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -11965.
# Date:                Mon, 21 Sep 2026   Deviance:                       23929.
# Time:                        00:37:24   Pearson chi2:                 4.13e+04
# No. Iterations:                     6   Pseudo R-squ. (CS):             0.1158
# Covariance Type:                  HC1
# ...
#                                              coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %% [markdown]
# ## 3. Monthly Odds Ratio Interpretation
#
# ### 3.1 Monthly Channel Comparison

# %%
params = m_time.params
cov = m_time.cov_params()

months = list(df['month'].cat.categories)
base_month = months[0] # Baseline month that starts with no interaction term (contact effect only)

def month_or_ci(month_label: str):
    # base_contact
    c_name = 'C(contact)[T.cellular]'
    b_c = params.get(c_name, 0.0)

    # beta_interaction for this month (if it's the baseline month, this will be 0)
    inter_name = f'C(contact)[T.cellular]:C(month)[T.{month_label}]'
    b_inter = params.get(inter_name, 0.0)

    b = b_c + b_inter

    # var(b) = var(beta_contact) + var(beta_interaction) + 2*cov(beta_contact, beta_interaction)
    v = cov.loc[c_name, c_name]
    if inter_name in cov.index:
        v += cov.loc[inter_name, inter_name] + 2 * cov.loc[c_name, inter_name]

    se = np.sqrt(v)

    or_ = np.exp(b)
    ci_low = np.exp(b - 1.96 * se)
    ci_high = np.exp(b + 1.96 * se)

    return or_, ci_low, ci_high

rows  = []
for month in months:
    or_, ci_low, ci_high = month_or_ci(month)
    rows.append({
        'term': f'cellular vs telephone ({month})',
        'month': month,
        'Odds Ratio cellular vs telephone': or_,
        'CI Lower': ci_low,
        'CI Upper': ci_high
    })

or_table = pd.DataFrame(rows).sort_values('month')
month_orders = ['mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']
or_table['month'] = pd.Categorical(or_table['month'], categories=month_orders, ordered=True)
or_table = or_table.sort_values('month')
or_table
# Out:
#                           term month  Odds Ratio cellular vs telephone  \
# 5  cellular vs telephone (mar)   mar                          1.721027
# 0  cellular vs telephone (apr)   apr                          0.816508
# 6  cellular vs telephone (may)   may                          3.191014
# 4  cellular vs telephone (jun)   jun                          8.699609
# 3  cellular vs telephone (jul)   jul                          1.816824
# 1  cellular vs telephone (aug)   aug                          0.837924
# 9  cellular vs telephone (sep)   sep                          3.113454
# 8  cellular vs telephone (oct)   oct                          0.762402
# 7  cellular vs telephone (nov)   nov                          0.790069
# 2  cellular vs telephone (dec)   dec                          1.540172
#
#    CI Lower   CI Upper
# 5  0.891725   3.321579
# 0  0.570474   1.168650
# 6  2.733939   3.724506
# 4  7.003149  10.807024
# 3  1.382986   2.386756
# 1  0.565574   1.241422
# ...

# %%
or_table['OR_greater_1'] = or_table['Odds Ratio cellular vs telephone'] > 1
or_table['CI_excludes_1'] = (or_table['CI Lower']>1) | (or_table['CI Upper']<1)

share_or_gt_1 = or_table['OR_greater_1'].mean() *100
count_ci_excl = or_table['CI_excludes_1'].sum()

share_or_gt_1, int(count_ci_excl)
# Out:
# (np.float64(60.0), 4)

# %% [markdown]
# Cellular contact has a point estimate above 1 in 6 of 10 months. Four months have 95% intervals that exclude 1: May 3.19, June 8.70, July 1.82, September 3.11. The other six include 1.
#
# The monthly differences are real in some months and indistinguishable from zero in others.
#
# <!-- KR: 10개월 중 6개월에서 점추정치 > 1. CI가 1을 제외하는 달은 4개: 5월 3.19, 6월 8.70, 7월 1.82, 9월 3.11. 나머지 6개월은 1을 포함. -->

# %% [markdown]
# ### 3.2 Visualisation Interpretation
#
# The monthly OR plot spans an order of magnitude.
#
# - June carries the largest estimate: OR 8.70, 95% CI 7.00–10.81.
# - May, July and September also sit above 1 with intervals that exclude it.
# - The remaining six months have intervals that include OR = 1. Four of those (April, August, October, November) have point estimates below 1.
#
# The channel association is strong in a few months and absent in others. One multiplier does not describe the campaign.
#
# <!-- KR: 6월 OR 8.70 (95% CI 7.00–10.81)이 최대. 5·7·9월도 CI가 1을 제외. 나머지 6개월은 CI가 1을 포함하고, 그중 4·8·10·11월은 점추정치가 1 미만. 채널 효과는 몇 개 달에 집중돼 있고 하나의 배수로 캠페인을 설명할 수 없다. -->

# %%
plt.figure(figsize=(10, 4))
plt.plot(or_table['month'], or_table['Odds Ratio cellular vs telephone'], marker = 'o')
plt.fill_between(
    or_table['month'],
    or_table['CI Lower'],
    or_table['CI Upper'],
    alpha=.2
)

plt.axhline(1, linestyle = '--')
plt.title('Monthly Odds Ratio: Cellular vs Telephone (with 95% CI)')
plt.ylabel('Odds Ratio')
plt.xlabel('Month')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.3 Conclusion
#
# After adjustment, cellular contact carries 2.3 times the conversion odds of telephone on average (OR 2.33, 95% CI 2.14–2.53). That average hides a wide spread: four months have intervals excluding 1, six do not, and point estimates run from 0.76 to 8.70.
#
# 84.7% of telephone contacts fall in May and June, against 24.2% of cellular contacts. Month and channel are therefore entangled in this data. The monthly pattern shows that a single channel multiplier is the wrong model; it does not tell us what any one month's channel effect is.
#
# For planning: do not assume one contact method is better in every month, and do not read a month-level OR as that month's channel effect.
#
# <!-- KR: 평균 adjusted OR 2.33 [2.14, 2.53]. 월별로는 CI가 1을 제외하는 달 4개, 포함하는 달 6개, 점추정치 0.76~8.70.
# telephone 접촉의 84.7%가 5·6월(cellular는 24.2%)에 몰려 있어 월과 채널이 얽혀 있다. 월별 패턴은 "단일 배수 모델이 틀렸다"는 근거이지, 특정 월의 채널 효과 값이 아니다. -->

# %% [markdown]
# ## 4. Limitations
#
# 1. Month has no year attached, so seasonality and macro timing cannot be separated.
# 2. The data is observational. Contact method was recorded, not assigned.
# 3. `default` was dropped (3 `yes` rows, 0 conversions) and `loan`'s `unknown` level was merged into `no` because it duplicated `housing`'s. Both were needed for the robust covariance to be finite; neither changes the contact estimate by more than 0.1 on the OR scale.
# 4. Interaction estimates in thin months are imprecise: December has 182 rows across both channels, March 546.
# 5. Macroeconomic controls are excluded because they move with month. Month-level estimates therefore absorb whatever economic conditions changed in that month.
#
# <!-- KR: 1) month에 연도가 없어 계절성과 거시 타이밍 분리 불가. 2) 관찰 데이터. 3) default 제거, loan unknown→no 병합(robust covariance가 유한해지기 위해 필요, contact 추정치 변화는 OR 척도에서 0.1 미만). 4) 표본이 얇은 달(12월 182행, 3월 546행)의 interaction 추정치는 부정확. 5) macro 변수는 month와 함께 움직여 제외. -->

# %% [markdown]
# ### Power BI Result Table Export

# %%
from pathlib import Path
import pandas as pd

Export_DIR = Path('../data/powerbi_exports')
Export_DIR.mkdir(parents = True, exist_ok=True)

def export_csv(df: pd.DataFrame, filename: str):
    out = Export_DIR / filename
    df.to_csv(out, index = False, encoding='utf-8')
    print(f'[Exported] {out.resolve()}')

# %%
# Export Timing Heterogeneity Table
timing_or = or_table.copy()

timing_or['month'] = timing_or['month'].astype(str) # Convert month to string for better compatibility in Power BI

export_csv(timing_or, 'timing_monthly_or_ci.csv')
# Out:
# [Exported] /Users/gayoungdan/Documents/DS MS/Job Hunting 💼/marketing-campaign-causal-evaluation/data/powerbi_exports/timing_monthly_or_ci.csv

# %% [markdown]
# ### Month X Channel Conversion Rate Table for Power BI

# %%
monthly_channel_conversion = (
    df.groupby(['month', 'contact'], observed=True)['y']
    .agg(['mean', 'count', 'sum'])
    .reset_index()
    .rename(columns = {'mean': 'conversion_rate',
                       'count': 'n',
                       'sum': 'conversions'})
)

monthly_channel_conversion.to_csv('../data/powerbi_exports/monthly_channel_conversion.csv', index = False, encoding='utf-8')
